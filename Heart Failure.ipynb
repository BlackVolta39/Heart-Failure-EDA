# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # READ DATASET

# %%
file_path = r"C:\Users\user\Desktop\Files\Lessons\Lessons\Sample Datas\heart_failure_clinical_records.csv"
df=pd.read_csv(file_path)

# %%
df
# Out:
#        age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0     55.0        0                       748         0                 45
# 1     65.0        0                        56         0                 25
# 2     45.0        0                       582         1                 38
# 3     60.0        1                       754         1                 40
# 4     95.0        1                       582         0                 30
# ...    ...      ...                       ...       ...                ...
# 4995  45.0        0                       582         1                 55
# 4996  60.0        1                       582         0                 30
# 4997  95.0        1                       112         0                 40
# 4998  65.0        1                       160         1                 20
# 4999  40.0        0                       244         0                 45
#
# ...

# %%
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  55.0        0                       748         0                 45
# 1  65.0        0                        56         0                 25
# 2  45.0        0                       582         1                 38
# 3  60.0        1                       754         1                 40
# 4  95.0        1                       582         0                 30
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    0  263358.03               1.3           137    1
# 1                    0  305000.00               5.0           130    1
# 2                    0  319000.00               0.9           140    0
# 3                    1  328000.00               1.2           126    1
# 4                    0  461000.00               2.0           132    1
#
#    smoking  time  DEATH_EVENT
# 0        1    88            0
# 1        0   207            0
# ...

# %%
#Tail
df.tail()
# Out:
#        age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 4995  45.0        0                       582         1                 55
# 4996  60.0        1                       582         0                 30
# 4997  95.0        1                       112         0                 40
# 4998  65.0        1                       160         1                 20
# 4999  40.0        0                       244         0                 45
#
#       high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 4995                    0   543000.0               1.0           132    0
# 4996                    1   127000.0               0.9           145    0
# 4997                    1   196000.0               1.0           138    0
# 4998                    0   327000.0               2.7           116    0
# 4999                    1   275000.0               0.9           140    0
#
#       smoking  time  DEATH_EVENT
# 4995        0   250            0
# ...

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %% [markdown]
# # Sanity Check Of Data

# %%
df.shape
# Out:
# (5000, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       5000 non-null   float64
#  1   anaemia                   5000 non-null   int64
#  2   creatinine_phosphokinase  5000 non-null   int64
#  3   diabetes                  5000 non-null   int64
#  4   ejection_fraction         5000 non-null   int64
#  5   high_blood_pressure       5000 non-null   int64
#  6   platelets                 5000 non-null   float64
#  7   serum_creatinine          5000 non-null   float64
#  8   serum_sodium              5000 non-null   int64
#  9   sex                       5000 non-null   int64
#  10  smoking                   5000 non-null   int64
#  11  time                      5000 non-null   int64
#  12  DEATH_EVENT               5000 non-null   int64
# dtypes: float64(3), int64(10)
# ...

# %%
#Finding Missing Values
df.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
#Finding Duplicates
df.duplicated().T
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995     True
# 4996     True
# 4997     True
# 4998     True
# 4999     True
# Length: 5000, dtype: bool

# %%
df.value_counts()
# Out:
# age   anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  smoking  time  DEATH_EVENT
# 82.0  1        855                       1         50                 1                    321000.00  1.0               145           0    0        30    1              33
# 60.0  1        582                       0         30                 1                    127000.00  0.9               145           0    0        95    0              28
# 53.0  0        207                       1         40                 0                    223000.00  1.2               130           0    0        214   0              28
# 50.0  1        121                       1         40                 0                    260000.00  0.7               130           1    0        175   0              28
# ...

# %% [markdown]
# # Exploratory Data Anaylsis(EDA)

# %%
#Descriptive Statistics
df.describe().T
# Out:
#                            count           mean           std      min  \
# age                       5000.0      60.288736     11.697243     40.0
# anaemia                   5000.0       0.474400      0.499394      0.0
# creatinine_phosphokinase  5000.0     586.760600    976.733979     23.0
# diabetes                  5000.0       0.439400      0.496364      0.0
# ejection_fraction         5000.0      37.734600     11.514855     14.0
# high_blood_pressure       5000.0       0.364800      0.481422      0.0
# platelets                 5000.0  265075.404370  97999.758622  25100.0
# serum_creatinine          5000.0       1.369106      1.009750      0.5
# serum_sodium              5000.0     136.808200      4.464236    113.0
# sex                       5000.0       0.645600      0.478379      0.0
# smoking                   5000.0       0.311800      0.463275      0.0
# time                      5000.0     130.678800     77.325928      4.0
# ...

# %%
#histogram to understand the distribution
for i in df.select_dtypes(include="number").columns:
    sns.histplot(data=df, x=i)
    plt.show()

# %%
#Boxplot to identify the outliers
for i in df.select_dtypes(include="number"). columns:
    sns.boxplot(data=df, x=i)
    plt.show()

# %%
df.select_dtypes(include="number").columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
#Scatter plot to understand the relationship
for i in ['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
       'ejection_fraction', 'high_blood_pressure', 'platelets',
       'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
       ]:
    sns.scatterplot(data=df,x=i,y='DEATH_EVENT')
    plt.show()

# %%
#Correlation with Heatmap to interpret the relation and multicolliniarity
s=df.select_dtypes(include="number").corr()

# %%
plt.figure(figsize=(20,20))
sns.heatmap(s,annot=True)
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %% [markdown]
# # Outlier Treatment

# %%
#Decide weather to do outlier treatment or not, how do you do it?
def wisker(col):
    q1,q3 = np.percentile(col,[25,75])
    iqr = q3-q1
    lw=q1-1.5*iqr
    uw=q3+1.5*iqr
    return lw,uw

# %%
wisker(df["serum_creatinine"])
# Out:
# (0.15000000000000024, 2.1499999999999995)

# %%
for i in ['serum_creatinine','serum_sodium','platelets','creatinine_phosphokinase','ejection_fraction']:
    lw,uw=wisker(df[i])
    df[i]=np.where(df[i]<lw,lw,df[i])
    df[i]=np.where(df[i]>uw,uw,df[i])

# %%
#Checking if your outliers have been resolved
for i in ['serum_creatinine','serum_sodium','platelets','creatinine_phosphokinase','ejection_fraction']:
    sns.boxplot(df[i])
    plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# # Duplicate And Garbage Values Treatment

# %%
df.drop_duplicates()
# Out:
#        age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0     55.0        0                     748.0         0               45.0
# 1     65.0        0                      56.0         0               25.0
# 2     45.0        0                     582.0         1               38.0
# 3     60.0        1                     754.0         1               40.0
# 4     95.0        1                     582.0         0               30.0
# ...    ...      ...                       ...       ...                ...
# 4731  75.0        0                     582.0         1               30.0
# 4855  73.0        0                     582.0         0               20.0
# 4862  45.0        0                     220.0         0               35.0
# 4965  40.0        1                     129.0         1               35.0
# 4972  70.0        0                     835.0         0               35.0
#
# ...

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')
